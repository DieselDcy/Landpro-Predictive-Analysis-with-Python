# %%
import joblib
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle
import seaborn as sns
from IPython.core.pylabtools import figsize
from IPython.display import IFrame
from pandas.api.types import CategoricalDtype
from pandas import merge
from scipy.sparse import csr_matrix
from sklearn import datasets
from sklearn import metrics
from sklearn import neighbors                           
from sklearn import tree, linear_model,neighbors   
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.datasets import load_boston
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import MissingIndicator
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Lasso 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge 
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import*
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import FeatureUnion
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVR
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %%
jdquote = pd.read_csv('JDQuote - Master.csv')
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,14,35,48,51,55,56,57,58,60,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sales = pd.read_csv('Daily Wholegood Sales Master.csv')

# %%
jdquote.head(10)
# Out:
#     QuoteID NameOfQuote QuoteType CreationDate ExpirationDate  \
# 0  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 1  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 2  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 3  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 4  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 5  18749945         NaN  Purchase     2-Jan-19       9-Jan-19
# 6  18749945         NaN  Purchase     2-Jan-19       9-Jan-19
# 7  18749945         NaN  Purchase     2-Jan-19       9-Jan-19
# 8  18749945         NaN  Purchase     2-Jan-19       9-Jan-19
# 9  18749945         NaN  Purchase     2-Jan-19       9-Jan-19
#
#   CurrentQuoteStatus CreatedLogon LastModifiedLogon SalesPersonName  \
# 0            Expired      X632257           X632257     HALE,DUSTIN
# 1            Expired      X632257           X632257     HALE,DUSTIN
# 2            Expired      X632257           X632257     HALE,DUSTIN
# ...

# %%
sales.head(10)
# Out:
#               Location  Stock #          Serial No                 Model  \
# 0     (18) Centre Hall   415773                NaN                RB2072
# 1     (18) Centre Hall   442612      M0L150A022123                 LT150
# 2     (18) Centre Hall   444184      M0G345E121228  GX345 48C TURF TIRES
# 3     (18) Centre Hall   445659                NaN          STEEL TRACKS
# 4     (18) Centre Hall   447626                NaN                 GT235
# 5     (18) Centre Hall   450223                NaN             155 W/48"
# 6     (18) Centre Hall   456486                NaN                  7000
# 7  (14) Fairmount City   402823  1LV5100RCHH400134                 5100R
# 8  (14) Fairmount City   405451  1P0540RXCHC003840                  540R
# 9        (04) Oakfield   389546  1M0835RAKJM010459               XUV835R
#
#          Make                     Description New/Used   Sale Date  \
# 0  JOHN DEERE         6' REAR BLADE /STRINGER        U  01/02/2019
# ...

# %%
jdquote.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330451 entries, 0 to 330450
# Data columns (total 63 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   QuoteID                      330431 non-null  object
#  1   NameOfQuote                  274895 non-null  object
#  2   QuoteType                    330431 non-null  object
#  3   CreationDate                 330431 non-null  object
#  4   ExpirationDate               330069 non-null  object
#  5   CurrentQuoteStatus           330431 non-null  object
#  6   CreatedLogon                 330431 non-null  object
#  7   LastModifiedLogon            330431 non-null  object
#  8   SalesPersonName              330415 non-null  object
#  9   CompanyName                  39667 non-null   object
#  10  ContactLastName              192953 non-null  object
#  11  ContactFirstName             191408 non-null  object
# ...

# %%
jdquote.describe()
# Out:
#             DealerID  EquipmentCode  EquipmentQuantity  DeereMDP  \
# count  330431.000000   3.243560e+05           324356.0       0.0
# mean    33971.326580   5.536126e+07                1.0       NaN
# std      1185.133544   5.662642e+06                0.0       NaN
# min     32466.000000   5.287746e+06                1.0       NaN
# 25%     32957.000000   5.171795e+07                1.0       NaN
# 50%     34629.000000   5.573276e+07                1.0       NaN
# 75%     34676.000000   6.021902e+07                1.0       NaN
# max     59198.000000   6.431094e+07                1.0       NaN
#
#        CPA/CA/Surcharge%  EquipmentManufactureYear   TradeInCode  \
# count                0.0              34183.000000  1.479800e+04
# mean                 NaN               2016.333002  5.171000e+06
# std                  NaN                 29.397462  4.199525e+05
# min                  NaN                201.000000  7.609680e+05
# ...

# %%
jdquote.shape
# Out:
# (330451, 63)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55377 entries, 0 to 55376
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          55377 non-null  object
#  1   Stock #           55377 non-null  int64
#  2   Serial No         52114 non-null  object
#  3   Model             55377 non-null  object
#  4   Make              55377 non-null  object
#  5   Description       55320 non-null  object
#  6   New/Used          55377 non-null  object
#  7   Sale Date         55377 non-null  object
#  8   Date Rcvd         55322 non-null  object
#  9   Sold To           53546 non-null  object
#  10  Total Sales       55377 non-null  object
#  11  Total Cost        55377 non-null  object
#  12  Gross Margin      55377 non-null  object
#  13  Gross Margin %    53788 non-null  object
#  14  salesperson_name  55374 non-null  object
#  15  Salesperson Code  55374 non-null  object
# ...

# %%
sales.describe()
# Out:
#              Stock #       DaysOld
# count   55377.000000  55322.000000
# mean   472012.389620    165.743701
# std     40347.045369    318.972396
# min      4218.000000     -6.000000
# 25%    465105.000000     22.000000
# 50%    479501.000000     69.000000
# 75%    494114.000000    194.000000
# max    517821.000000   6788.000000

# %%
sales.shape
# Out:
# (55377, 20)

# %%
jdquote.columns
# Out:
# Index(['QuoteID', 'NameOfQuote', 'QuoteType', 'CreationDate', 'ExpirationDate',
#        'CurrentQuoteStatus', 'CreatedLogon', 'LastModifiedLogon',
#        'SalesPersonName', 'CompanyName', 'ContactLastName', 'ContactFirstName',
#        'City', 'StateProvince', 'PostalZip', 'Phone', 'Customer Email',
#        'DealerID', 'DealerName', 'DealerCity', 'DealerState', 'EquipmentCode',
#        'EquipmentDescription', 'EquipmentType', 'EquipmentSerialNumber',
#        'EquipmentQuantity', 'EquipmentAmount', 'DeereMDP', 'CPA/CA/Surcharge%',
#        'SellingPrice', 'EquipmentManufacturer', 'EquipmentCategoryDesc',
#        'EquipmentSubCategoryDesc', 'EquipmentManufactureYear',
#        'EquipmentModel', 'StockNumber', 'IncentiveProgramNumber',
#        'EquipmentStatus', 'TradeInCode', 'TradeInDescription',
#        'TradeInSerialNumber', 'TradeInQuantity', 'NetTradeValue',
#        'TradeInManufacturer', 'TradeInCategoryDesc', 'TradeInSubCategoryDesc',
# ...

# %%
sales.columns
# Out:
# Index(['Location', 'Stock #', 'Serial No', 'Model', 'Make', 'Description',
#        'New/Used', 'Sale Date', 'Date Rcvd', 'Sold To', 'Total Sales',
#        'Total Cost', 'Gross Margin', 'Gross Margin %', 'salesperson_name',
#        'Salesperson Code', 'Acquired By', 'DaysOld', 'category',
#        'sold_to_code'],
#       dtype='object')

# %%
base = pd.read_csv('Simon Base-Implement.csv')

# %%
base.head(10)
# Out:
#              EquipmentCategoryDesc Base/Implement
# 0                      4WD Loaders           Base
# 1                      AG Tractors           Base
# 2          Agriculture Attachments      Implement
# 3           Agriculture Implements      Implement
# 4                         Backhoes      Implement
# 5               Combine Harvesting           Base
# 6                Commercial Mowing           Base
# 7  Commercial Worksite Attachments      Implement
# 8              Compact 4WD Loaders           Base
# 9              Compact Attachments      Implement

# %%
base.describe()
# Out:
#        EquipmentCategoryDesc Base/Implement
# count                     45             45
# unique                    45              2
# top     Nutrient Application           Base
# freq                       1             27

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EquipmentCategoryDesc  45 non-null     object
#  1   Base/Implement         45 non-null     object
# dtypes: object(2)
# memory usage: 848.0+ bytes

# %%
base.shape
# Out:
# (45, 2)

# %%
base.columns
# Out:
# Index(['EquipmentCategoryDesc', 'Base/Implement'], dtype='object')

# %%
jdquote1 = jdquote.merge(base,how = 'left',on = 'EquipmentCategoryDesc')

# %%
jdquote1.head(10)
# Out:
#     QuoteID NameOfQuote QuoteType CreationDate ExpirationDate  \
# 0  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 1  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 2  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 3  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 4  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 5  18749945         NaN  Purchase     2-Jan-19       9-Jan-19
# 6  18749945         NaN  Purchase     2-Jan-19       9-Jan-19
# 7  18749945         NaN  Purchase     2-Jan-19       9-Jan-19
# 8  18749945         NaN  Purchase     2-Jan-19       9-Jan-19
# 9  18749945         NaN  Purchase     2-Jan-19       9-Jan-19
#
#   CurrentQuoteStatus CreatedLogon LastModifiedLogon SalesPersonName  \
# 0            Expired      X632257           X632257     HALE,DUSTIN
# 1            Expired      X632257           X632257     HALE,DUSTIN
# 2            Expired      X632257           X632257     HALE,DUSTIN
# ...

# %%
sales.shape
# Out:
# (55377, 20)

# %%
jdquote.shape
# Out:
# (330451, 63)

# %%
jdquote1.shape
# Out:
# (330451, 64)

# %%
jdquote1.shape[0]
# Out:
# 330451

# %%
m1 = []
for i in range(10000):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m1.append('0')
            else:
                m1.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m1.append(jdquote1['ContactFirstName'][i])
            else:
                m1.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m1.append(jdquote1['CompanyName'][i])
            else:
                m1.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m1.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m1.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
m1
# Out:
# ['FOSKIT KEVIN',
#  'FOSKIT KEVIN',
#  'FOSKIT KEVIN',
#  'FOSKIT KEVIN',
#  'FOSKIT KEVIN',
#  'JA LENE FARM',
#  'JA LENE FARM',
#  'JA LENE FARM',
#  'JA LENE FARM',
#  'JA LENE FARM',
#  'JA LENE FARM',
#  'DONOVAN MIKE',
#  'CONGDON THOMAS',
#  'CONGDON THOMAS',
#  'CONGDON THOMAS',
#  'VALLEY VIEW FARMS',
#  'VALLEY VIEW FARMS',
#  'VALLEY VIEW FARMS',
#  'VALLEY VIEW FARMS',
#  'VALLEY VIEW FARMS',
#  'VALLEY VIEW FARMS',
#  'VALLEY VIEW FARMS',
#  'TOWN OF NIAGARA',
#  'DECKER RICHARD',
#  'DECKER RICHARD',
#  'DECKER RICHARD',
#  'NIAGARA FALLS HOUSING AUTH',
#  'NIAGARA FALLS HOUSING AUTH',
#  'NIAGARA FALLS HOUSING AUTH',
#  'WARREN STATE HOSPITAL',
#  'WARREN STATE HOSPITAL',
#  'VILLAGE OF GENESEO/DPW',
#  'HILTON CENTRAL SCHOOLS',
#  'MCCLELLAND RON',
#  'MCCLELLAND RON',
#  'HILLY ORCHARD LLC',
#  'HOUSER TIMOTHY',
#  'HOUSER TIMOTHY',
#  'HOUSER TIMOTHY',
#  'HOUSER TIMOTHY',
#  'SHAH RAJNI',
#  'JENSEN PHILIP',
#  'JENSEN PHILIP',
# ...

# %%
m2 = []
for i in range(10000,20000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m2.append('0')
            else:
                m2.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m2.append(jdquote1['ContactFirstName'][i])
            else:
                m2.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m2.append(jdquote1['CompanyName'][i])
            else:
                m2.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m2.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m2.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
m2
# Out:
# ['DUTCH LANE FARMS KELLY EDWARD',
#  'DUTCH LANE FARMS KELLY EDWARD',
#  '0',
#  '0',
#  'LEBO MELVIN',
#  'LEBO MELVIN',
#  'DALLEN TERRY',
#  'Ross Tim',
#  'Ross Tim',
#  'SECONDINO JIM',
#  'neeley andrew',
#  'neeley andrew',
#  'neeley andrew',
#  'SANTANA EUSTOLIA',
#  'STEFFEN STEVEN',
#  'BRAKE RONALD',
#  'BRAKE RONALD',
#  '0',
#  '0',
#  '0',
#  'FITE RONALD',
#  'NIAGARA GOLF PARTNERS',
#  'NIAGARA GOLF PARTNERS',
#  'NIAGARA GOLF PARTNERS',
#  'NIAGARA GOLF PARTNERS',
#  'NIAGARA GOLF PARTNERS',
#  'BURDICK DAVID',
#  'DRIVER DANIEL',
#  'CURB SOLUTIONS INC.',
#  'CURB SOLUTIONS INC.',
#  'CURB SOLUTIONS INC.',
#  'SCHRANTZ BRIAN',
#  'SCHRANTZ BRIAN',
#  'SCHRANTZ BRIAN',
#  'ERDMAN JUSTIN',
#  'PENNCREST SCHOOL DISTRICT',
#  'CITY OF OLEAN',
#  'CITY OF LOCK HAVEN',
#  'CITY OF LOCK HAVEN',
#  'CALVARY CEMETERY',
#  'STEHR TRACY',
#  'STEHR TRACY',
#  'STEHR TRACY',
#  'STEHR TRACY',
#  'PENNCREST SCHOOL DISTRICT',
#  'PENNCREST SCHOOL DISTRICT',
# ...

# %%
for i in m2:
    m1.append(i)

# %%
m3 = []
for i in range(20000,30000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m3.append('0')
            else:
                m3.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m3.append(jdquote1['ContactFirstName'][i])
            else:
                m3.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m3.append(jdquote1['CompanyName'][i])
            else:
                m3.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m3.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m3.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m3:
    m1.append(i)

# %%
m4 = []
for i in range(30000,40000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m4.append('0')
            else:
                m4.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m4.append(jdquote1['ContactFirstName'][i])
            else:
                m4.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m4.append(jdquote1['CompanyName'][i])
            else:
                m4.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m4.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m4.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m4:
    m1.append(i)

# %%
m5 = []
for i in range(40000,50000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m5.append('0')
            else:
                m5.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m5.append(jdquote1['ContactFirstName'][i])
            else:
                m5.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m5.append(jdquote1['CompanyName'][i])
            else:
                m5.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m5.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m5.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m5:
    m1.append(i)

# %%
m6 = []
for i in range(50000,60000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m6.append('0')
            else:
                m6.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m6.append(jdquote1['ContactFirstName'][i])
            else:
                m6.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m6.append(jdquote1['CompanyName'][i])
            else:
                m6.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m6.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m6.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m6:
    m1.append(i)

# %%
m7 = []
for i in range(60000,70000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m7.append('0')
            else:
                m7.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m7.append(jdquote1['ContactFirstName'][i])
            else:
                m7.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m7.append(jdquote1['CompanyName'][i])
            else:
                m7.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m7.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m7.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m7:
    m1.append(i)

# %%
m8 = []
for i in range(70000,80000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m8.append('0')
            else:
                m8.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m8.append(jdquote1['ContactFirstName'][i])
            else:
                m8.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m8.append(jdquote1['CompanyName'][i])
            else:
                m8.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m8.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m8.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m8:
    m1.append(i)

# %%
m9 = []
for i in range(80000,90000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m9.append('0')
            else:
                m9.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m9.append(jdquote1['ContactFirstName'][i])
            else:
                m9.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m9.append(jdquote1['CompanyName'][i])
            else:
                m9.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m9.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m9.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m9:
    m1.append(i)

# %%
m10 = []
for i in range(90000,100000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m10.append('0')
            else:
                m10.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m10.append(jdquote1['ContactFirstName'][i])
            else:
                m10.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m10.append(jdquote1['CompanyName'][i])
            else:
                m10.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m10.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m10.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m10:
    m1.append(i)

# %%
len(m1)
# Out:
# 100000

# %%
m11= []
for i in range(100000,110000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m11.append('0')
            else:
                m11.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m11.append(jdquote1['ContactFirstName'][i])
            else:
                m11.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m11.append(jdquote1['CompanyName'][i])
            else:
                m11.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m11.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m11.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m11:
    m1.append(i)

# %%
m12= []
for i in range(110000,120000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m12.append('0')
            else:
                m12.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m12.append(jdquote1['ContactFirstName'][i])
            else:
                m12.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m12.append(jdquote1['CompanyName'][i])
            else:
                m12.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m12.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m12.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m12:
    m1.append(i)

# %%
m13= []
for i in range(120000,130000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m13.append('0')
            else:
                m13.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m13.append(jdquote1['ContactFirstName'][i])
            else:
                m13.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m13.append(jdquote1['CompanyName'][i])
            else:
                m13.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m13.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m13.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m13:
    m1.append(i)

# %%
m14 = []
for i in range(130000,140000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m14.append('0')
            else:
                m14.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m14.append(jdquote1['ContactFirstName'][i])
            else:
                m14.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m14.append(jdquote1['CompanyName'][i])
            else:
                m14.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m14.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m14.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m14:
    m1.append(i)

# %%
m15 = []
for i in range(140000,150000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m15.append('0')
            else:
                m15.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m15.append(jdquote1['ContactFirstName'][i])
            else:
                m15.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m15.append(jdquote1['CompanyName'][i])
            else:
                m15.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m15.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m15.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m15:
    m1.append(i)

# %%
m16 = []
for i in range(150000,160000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m16.append('0')
            else:
                m16.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m16.append(jdquote1['ContactFirstName'][i])
            else:
                m16.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m16.append(jdquote1['CompanyName'][i])
            else:
                m16.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m16.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m16.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m16:
    m1.append(i)

# %%
m17 = []
for i in range(160000,170000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m17.append('0')
            else:
                m17.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m17.append(jdquote1['ContactFirstName'][i])
            else:
                m17.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m17.append(jdquote1['CompanyName'][i])
            else:
                m17.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m17.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m17.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m17:
    m1.append(i)

# %%
m18 = []
for i in range(170000,180000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m18.append('0')
            else:
                m18.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m18.append(jdquote1['ContactFirstName'][i])
            else:
                m18.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m18.append(jdquote1['CompanyName'][i])
            else:
                m18.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m18.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m18.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m18:
    m1.append(i)

# %%
m19 = []
for i in range(180000,190000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m19.append('0')
            else:
                m19.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m19.append(jdquote1['ContactFirstName'][i])
            else:
                m19.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m19.append(jdquote1['CompanyName'][i])
            else:
                m19.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m19.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m19.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m19:
    m1.append(i)

# %%
m20 = []
for i in range(190000,200000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m20.append('0')
            else:
                m20.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m20.append(jdquote1['ContactFirstName'][i])
            else:
                m20.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m20.append(jdquote1['CompanyName'][i])
            else:
                m20.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m20.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m20.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m20:
    m1.append(i)

# %%
m21 = []
for i in range(200000,210000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m21.append('0')
            else:
                m21.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m21.append(jdquote1['ContactFirstName'][i])
            else:
                m21.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m21.append(jdquote1['CompanyName'][i])
            else:
                m21.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m21.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m21.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m21:
    m1.append(i)

# %%
m22 = []
for i in range(210000,220000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m22.append('0')
            else:
                m22.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m22.append(jdquote1['ContactFirstName'][i])
            else:
                m22.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m22.append(jdquote1['CompanyName'][i])
            else:
                m22.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m22.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m22.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m22:
    m1.append(i)

# %%
m23 = []
for i in range(220000,230000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m23.append('0')
            else:
                m23.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m23.append(jdquote1['ContactFirstName'][i])
            else:
                m23.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m23.append(jdquote1['CompanyName'][i])
            else:
                m23.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m23.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m23.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m23:
    m1.append(i)

# %%
m24 = []
for i in range(230000,240000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m24.append('0')
            else:
                m24.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m24.append(jdquote1['ContactFirstName'][i])
            else:
                m24.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m24.append(jdquote1['CompanyName'][i])
            else:
                m24.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m24.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m24.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m24:
    m1.append(i)

# %%
m25 = []
for i in range(240000,250000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m25.append('0')
            else:
                m25.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m25.append(jdquote1['ContactFirstName'][i])
            else:
                m25.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m25.append(jdquote1['CompanyName'][i])
            else:
                m25.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m25.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m25.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m25:
    m1.append(i)

# %%
m26 = []
for i in range(250000,260000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m26.append('0')
            else:
                m26.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m26.append(jdquote1['ContactFirstName'][i])
            else:
                m26.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m26.append(jdquote1['CompanyName'][i])
            else:
                m26.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m26.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m26.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m26:
    m1.append(i)

# %%
m27 = []
for i in range(260000,270000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m27.append('0')
            else:
                m27.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m27.append(jdquote1['ContactFirstName'][i])
            else:
                m27.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m27.append(jdquote1['CompanyName'][i])
            else:
                m27.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m27.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m27.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m27:
    m1.append(i)

# %%
m28 = []
for i in range(270000,280000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m28.append('0')
            else:
                m28.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m28.append(jdquote1['ContactFirstName'][i])
            else:
                m28.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m28.append(jdquote1['CompanyName'][i])
            else:
                m28.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m28.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m28.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m28:
    m1.append(i)

# %%
m29 = []
for i in range(280000,290000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m29.append('0')
            else:
                m29.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m29.append(jdquote1['ContactFirstName'][i])
            else:
                m29.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m29.append(jdquote1['CompanyName'][i])
            else:
                m29.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m29.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m29.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m29:
    m1.append(i)

# %%
m30 = []
for i in range(290000,300000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m30.append('0')
            else:
                m30.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m30.append(jdquote1['ContactFirstName'][i])
            else:
                m30.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m30.append(jdquote1['CompanyName'][i])
            else:
                m30.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m30.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m30.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m30:
    m1.append(i)

# %%
m31 = []
for i in range(300000,310000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m31.append('0')
            else:
                m31.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m31.append(jdquote1['ContactFirstName'][i])
            else:
                m31.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m31.append(jdquote1['CompanyName'][i])
            else:
                m31.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m31.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m31.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m31:
    m1.append(i)

# %%
m32 = []
for i in range(310000,320000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m32.append('0')
            else:
                m32.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m32.append(jdquote1['ContactFirstName'][i])
            else:
                m32.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m32.append(jdquote1['CompanyName'][i])
            else:
                m32.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m32.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m32.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m32:
    m1.append(i)

# %%
m33 = []
for i in range(320000,330000,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m33.append('0')
            else:
                m33.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m33.append(jdquote1['ContactFirstName'][i])
            else:
                m33.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m33.append(jdquote1['CompanyName'][i])
            else:
                m33.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m33.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m33.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m33:
    m1.append(i)

# %%
m34 = []
for i in range(330000,330451,1):
    if jdquote1['CompanyName'].isna()[i]:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m34.append('0')
            else:
                m34.append(jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m34.append(jdquote1['ContactFirstName'][i])
            else:
                m34.append(jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])
    else:
        if jdquote1['ContactFirstName'].isna()[i]:
            if jdquote1['ContactLastName'].isna()[i]:
                m34.append(jdquote1['CompanyName'][i])
            else:
                m34.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i])
        else:
            if jdquote1['ContactLastName'].isna()[i]:
                m34.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactFirstName'][i])
            else:
                m34.append(jdquote1['CompanyName'][i]+' '+jdquote1['ContactLastName'][i]+' '+jdquote1['ContactFirstName'][i])

# %%
for i in m34:
    m1.append(i)

# %%
m = {'CustomerName':m1}

# %%
data1 = pd.DataFrame(m)

# %%
data1.head()
# Out:
#    CustomerName
# 0  FOSKIT KEVIN
# 1  FOSKIT KEVIN
# 2  FOSKIT KEVIN
# 3  FOSKIT KEVIN
# 4  FOSKIT KEVIN

# %%
data1.shape
# Out:
# (330451, 1)

# %%
data1.to_csv('data.csv')

# %%
jdquote1['CustomerName'] = m1

# %%
jdquote1.head()
# Out:
#     QuoteID NameOfQuote QuoteType CreationDate ExpirationDate  \
# 0  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 1  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 2  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 3  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 4  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
#
#   CurrentQuoteStatus CreatedLogon LastModifiedLogon SalesPersonName  \
# 0            Expired      X632257           X632257     HALE,DUSTIN
# 1            Expired      X632257           X632257     HALE,DUSTIN
# 2            Expired      X632257           X632257     HALE,DUSTIN
# 3            Expired      X632257           X632257     HALE,DUSTIN
# 4            Expired      X632257           X632257     HALE,DUSTIN
#
#   CompanyName  ... Competitor model Comments on Lost Deal   Net Cost  \
# 0         NaN  ...              NaN                   NaN  25,600.00
# ...

# %%
jdquote1.shape
# Out:
# (330451, 67)

# %%
jdquote1 = jdquote1.drop(['FullName','Sold To2'],axis = 1)

# %%
jdquote1.shape
# Out:
# (330451, 65)

# %%
jdquote1.head()
# Out:
#     QuoteID NameOfQuote QuoteType CreationDate ExpirationDate  \
# 0  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 1  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 2  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 3  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
# 4  18744620       Kevin  Purchase     2-Jan-19       9-Jan-19
#
#   CurrentQuoteStatus CreatedLogon LastModifiedLogon SalesPersonName  \
# 0            Expired      X632257           X632257     HALE,DUSTIN
# 1            Expired      X632257           X632257     HALE,DUSTIN
# 2            Expired      X632257           X632257     HALE,DUSTIN
# 3            Expired      X632257           X632257     HALE,DUSTIN
# 4            Expired      X632257           X632257     HALE,DUSTIN
#
#   CompanyName  ... Reason For Lost Sales Sales Lost To Competitor model  \
# 0         NaN  ...                   NaN           NaN              NaN
# ...

# %%
jdquote1.to_csv('jdquote.csv')

# %%
sales.shape
# Out:
# (55377, 20)

# %%
sales.head()
# Out:
#            Location  Stock #      Serial No                 Model        Make  \
# 0  (18) Centre Hall   415773            NaN                RB2072  JOHN DEERE
# 1  (18) Centre Hall   442612  M0L150A022123                 LT150  JOHN DEERE
# 2  (18) Centre Hall   444184  M0G345E121228  GX345 48C TURF TIRES  JOHN DEERE
# 3  (18) Centre Hall   445659            NaN          STEEL TRACKS     GROUSER
# 4  (18) Centre Hall   447626            NaN                 GT235  JOHN DEERE
#
#                Description New/Used   Sale Date   Date Rcvd  \
# 0  6' REAR BLADE /STRINGER        U  01/02/2019  01/07/2014
# 1        L&G GEAR W/38" DE        U  01/02/2019  02/25/2015
# 2              L&G TRACTOR        U  01/02/2019  06/30/2015
# 3    TRACKS FOR SKID STEER        U  01/02/2019  10/29/2015
# 4          L&G GT235 W/48C        U  01/02/2019  05/04/2016
#
#                         Sold To Total Sales  Total Cost Gross Margin  \
# ...

# %%
quote_sales = pd.merge(jdquote1,sales,left_on = 'CustomerName',right_on = 'Sold To')

# %%
quote_sales.shape
# Out:
# (167484, 85)

# %%
quote_sales.head()
# Out:
#     QuoteID     NameOfQuote QuoteType CreationDate ExpirationDate  \
# 0  18746816  Valley View-7R  Purchase     2-Jan-19      31-Jan-19
# 1  18746816  Valley View-7R  Purchase     2-Jan-19      31-Jan-19
# 2  18746816  Valley View-7R  Purchase     2-Jan-19      31-Jan-19
# 3  18746816  Valley View-7R  Purchase     2-Jan-19      31-Jan-19
# 4  18746816  Valley View-7R  Purchase     2-Jan-19      31-Jan-19
#
#   CurrentQuoteStatus CreatedLogon LastModifiedLogon  SalesPersonName  \
# 0            Expired      X3C2252           X3C2252  KELSEY,THOMAS R
# 1            Expired      X3C2252           X3C2252  KELSEY,THOMAS R
# 2            Expired      X3C2252           X3C2252  KELSEY,THOMAS R
# 3            Expired      X3C2252           X3C2252  KELSEY,THOMAS R
# 4            Expired      X3C2252           X3C2252  KELSEY,THOMAS R
#
#          CompanyName  ...  Total Sales    Total Cost  Gross Margin  \
# 0  VALLEY VIEW FARMS  ...  $45,900.00    $37,214.82     $8,685.18
# ...

# %%
quote_sales.to_csv('quote_sales.csv',encoding = 'utf-8')
